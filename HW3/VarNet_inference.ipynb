# %%
# Clone VarNet
# !git clone https://github.com/skandlab/VarNet.git
# %cd VarNet
# Out:
# Cloning into 'VarNet'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 89 (delta 13), reused 4 (delta 0), pack-reused 59 (from 1)
# Receiving objects: 100% (89/89), 92.19 MiB | 22.81 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Updating files: 100% (28/28), done.
# /content/VarNet

# %% [markdown]
# **Before installing the required packages, replace the requirements.txt file inside the VarNet directory with the provided one.**
#
# *Ignore TensorFlow-related installation errors — they won’t affect the notebook run.*

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/VarNet/data

# !cp /content/drive/MyDrive/compGenomics/*.bam /content/VarNet/data
# !cp /content/drive/MyDrive/compGenomics/*.bai /content/VarNet/data
# !cp /content/drive/MyDrive/compGenomics/reference.fa /content/VarNet/data
# !cp /content/drive/MyDrive/compGenomics/reference.fa.fai /content/VarNet/data

# %%
# %cd VarNet
# Out:
# /content/VarNet

# %%
# !python filter.py \
    --sample_name HCC1395 \
    --normal_bam /content/VarNet/data/normal.bam \
      --tumor_bam /content/VarNet/data/tumor.bam \
    --processes 2 \
    --output_dir varnet_outputs \
    --reference /content/VarNet/data/reference.fa

# %%
# !python predict.py \
	  --sample_name HCC1395 \
    --normal_bam /content/VarNet/data/normal.bam \
    --tumor_bam /content/VarNet/data/tumor.bam \
    --processes 2 \
    --output_dir varnet_outputs \
    --reference /content/VarNet/data/reference.fa
# Out:
# ('Number of SNV candidates: ', 131)
# ('SNV PREDICTION BATCH:', 0)
# ('SNV PREDICTION BATCH:', 1)
# 1/1 [==============================] - 1s 923ms/step
# /content/VarNet/snvs/predict.py:191: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(results_dict, ignore_index = True)
# 1/1 [==============================] - 0s 73ms/step
# /content/VarNet/snvs/predict.py:191: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(results_dict, ignore_index = True)
# ('SNV Batch Complete:', 0)
# ('SNV PREDICTION BATCH:', 2)
# 1/1 [==============================] - 1s 591ms/step
# /content/VarNet/snvs/predict.py:191: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
